# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('Files/iris-data.csv', index_col = 0)

# %%
df.columns
# Out:
# Index(['lar.sepalo', 'anc.sepalo', 'lar.petalo', 'anc.petalo', 'tipo_flor'], dtype='object')

# %%
df.tipo_flor.value_counts()
# Out:
# 2.0    50
# 1.0    50
# 0.0    50
# Name: tipo_flor, dtype: int64

# %%
y = df['lar.petalo']

# %%
fig, ax = plt.subplots()
ax.set_title('Variable original')
ax.hist(y, bins = 30)
ax.axvline(x = np.mean(y), c = 'k', label= 'media', linestyle = '--')
ax.axvline(x = np.mean(y) + np.std(y), c = 'r', label= 'desviacion est.', linestyle = '--')
ax.legend()

# %%
fig, ax = plt.subplots()
# cambio de variable para estandarizar
ax.set_title('Variable original')
# Estandarizado
ax.hist(y -  np.mean(y), bins = 30)
ax.axvline(x = np.mean(y -  np.mean(y)), c = 'k', label= 'media', linestyle = '--')
ax.axvline(x = np.mean(y) + np.std(y), c = 'r', label= 'desviacion est.', linestyle = '--')
ax.legend()

# %%
fig, ax = plt.subplots()
# cambio de variable para estandarizar
z = (y - np.mean(y)) / np.std(y)


ax.set_title('Estandarización de la variable')
# Original
ax.hist(y, bins = 30, alpha = 0.3)
ax.axvline(x = np.mean(y), color='black', label='media', linestyle='--', alpha = 0.5)
ax.axvline(x = np.mean(y) + np.std(y), color='red', label='desv. est.', linestyle='--', alpha = 0.5)

# Estandarizado
ax.hist(z, bins = 30)
ax.axvline(x = np.mean(z), color='black', label='media estand.', linestyle='--')
ax.axvline(x = np.mean(z) + np.std(z), color='red', label='desv. est. estand.', linestyle='--')

ax.legend()

# %% [markdown]
# Covarianza y correlación

# %%
fig, ax = plt.subplots()
ax.scatter(df['lar.petalo'], df['lar.sepalo'], alpha = 0.7)
ax.set_xlabel('lar.petalo')
ax.set_ylabel('lar.sepalo')
ax.autoscale()
#veamos ahora la relación entre dos variables, estas son:

#largo de petalo
#largo de sepalo

# %%
np.cov(df['lar.petalo'], df['lar.sepalo'])
#Veamos la covarianza:
# Out:
# array([[3.11627785, 1.27431544],
#        [1.27431544, 0.68569351]])

# %%
corr = df.corr(method = 'kendall')

# %%
sns.heatmap(corr, xticklabels = corr.columns, yticklabels = corr.columns )
